# %%
import pandas as pd

# %%
df=pd.read_csv('blood_donation_eligibility_500.csv')

# %%
df.head()
# Out:
#        Name  Age  ...  Disease History (Yes=1/No=0)  Eligible
# 0  Person_1   64  ...                             0         0
# 1  Person_2   56  ...                             1         0
# 2  Person_3   37  ...                             0         1
# 3  Person_4   50  ...                             0         0
# 4  Person_5   60  ...                             1         0
#
# [5 rows x 8 columns]

# %%
x= df[['Age', 'Weight (kg)', 'Hemoglobin (g/dL)', 
        'Last Donation (months)', 'Disease History (Yes=1/No=0)']]

y=df['Eligible']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)  
model.score(x_test,y_test)
# Out:
# 0.89

# %%
from sklearn.metrics import accuracy_score
y_pred=model.predict(x_test)
print("Test Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Test Accuracy: 0.89

# %%
import joblib

# %%
joblib.dump(model, 'blood_donation_model.pkl')
# Out:
# ['blood_donation_model.pkl']

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
model.score(x_train,y_train)
# Out:
# 0.20824710872360053

# %%
df[['Age', 'Weight (kg)', 'Hemoglobin (g/dL)', 'Last Donation (months)']].hist(bins=15, figsize=(12,8), color='skyblue', edgecolor='black')
plt.suptitle('Distribution of Numerical Features', fontsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df[['Age', 'Weight (kg)', 'Hemoglobin (g/dL)', 'Last Donation (months)']].hist(bins=15, figsize=(12,8), color='skyblue', edgecolor='black')
#       2 plt.suptitle('Distribution of Numerical Features', fontsize=16)
#       3 plt.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\plotting\_core.py:250, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     145 def hist_frame(
#     146     data: DataFrame,
#     147     column: IndexLabel | None = None,
#    (...)    162     **kwargs,
#     163 ):
#     164     """
#     165     Make a histogram of the DataFrame's columns.
#     166
# ...

# %%
# Out:
#   Cell In[16], line 1
#     pip install matplotlib
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('blood_donation_eligibility_500.csv')

# Histograms
df[['Age', 'Weight (kg)', 'Hemoglobin (g/dL)', 'Last Donation (months)']].hist(
    bins=15, figsize=(12,8), color='skyblue', edgecolor='black'
)
plt.suptitle('Distribution of Numerical Features', fontsize=16)
plt.show()

# Count plot
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Eligible', palette='pastel')
plt.title('Eligible vs Not Eligible Donors')
plt.xlabel('Eligible')
plt.ylabel('Count')
plt.show()

# Correlation heatmap
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Features')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
#       5 df = pd.read_csv('blood_donation_eligibility_500.csv')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
python -m pip install --upgrade pip
# Out:
#   Cell In[29], line 1
#     python -m pip install --upgrade pip
#               ^
# SyntaxError: invalid syntax

# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 python --version
#
# NameError: name 'python' is not defined
